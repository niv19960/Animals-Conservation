# %%
import pandas as pd

# %% [markdown]
# ### Understanding our data

# %%
animals_df = pd.read_csv("animals first data.csv")

# %%
copy_df = animals_df.copy()

# %%
animals_df
# Out:
#                   Scientific Name     Class          Order         Family  \
# 0              Canis lupus arctos  mammalia      carnivora        canidae
# 1                  Vulpes lagopus  mammalia      carnivora        canidae
# 2         Tamiasciurus hudsonicus  mammalia       rodentia      sciuridae
# 3                     Canis lupus  mammalia      carnivora        canidae
# 4                 Mustela erminea  mammalia      carnivora     mustelidae
# ...                           ...       ...            ...            ...
# 1584   Melanerpes erythrocephalus      aves     piciformes        picidae
# 1585              Mniotilta varia      aves  passeriformes      parulidae
# 1586  Leuconotopicus albolarvatus      aves     piciformes        picidae
# 1587           Dryobates borealis      aves     piciformes        picidae
# 1588        Cistothorus palustris      aves  passeriformes  troglodytidae
#
#       Trend  Status  Life Span (years)  Length (cm)  Weight (kg)  Is Social  \
# ...

# %%
animals_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1589 entries, 0 to 1588
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Scientific Name           1589 non-null   object
#  1   Class                     1589 non-null   object
#  2   Order                     1589 non-null   object
#  3   Family                    1589 non-null   object
#  4   Trend                     1291 non-null   float64
#  5   Status                    1492 non-null   float64
#  6   Life Span (years)         1525 non-null   float64
#  7   Length (cm)               1474 non-null   float64
#  8   Weight (kg)               1447 non-null   float64
#  9   Is Social                 1589 non-null   int64
#  10  Is Nocturnal              1589 non-null   int64
#  11  Diet                      1582 non-null   float64
#  12  Mating Behavior           1199 non-null   float64
# ...

# %%
animals_df.describe(include='all')
# Out:
#                Scientific Name     Class         Order   Family        Trend  \
# count                     1589      1589          1589     1589  1291.000000
# unique                    1588         3            60      255          NaN
# top     Arctocephalus pusillus  mammalia  artiodactyla  bovidae          NaN
# freq                         2       865           203       91          NaN
# mean                       NaN       NaN           NaN      NaN     0.625871
# std                        NaN       NaN           NaN      NaN     0.713272
# min                        NaN       NaN           NaN      NaN     0.000000
# 25%                        NaN       NaN           NaN      NaN     0.000000
# 50%                        NaN       NaN           NaN      NaN     0.000000
# 75%                        NaN       NaN           NaN      NaN     1.000000
# max                        NaN       NaN           NaN      NaN     2.000000
#
# ...

# %%
animals_df.describe()
# Out:
#              Trend       Status  Life Span (years)  Length (cm)  \
# count  1291.000000  1492.000000        1525.000000  1474.000000
# mean      0.625871     0.274129          19.516066    93.221303
# std       0.713272     0.446224          15.766117   165.950416
# min       0.000000     0.000000           1.000000     0.000000
# 25%       0.000000     0.000000          10.000000    27.500000
# 50%       0.000000     0.000000          16.000000    53.000000
# 75%       1.000000     1.000000          25.000000   100.000000
# max       2.000000     1.000000         162.500000  2750.000000
#
#          Weight (kg)    Is Social  Is Nocturnal         Diet  Mating Behavior  \
# count    1447.000000  1589.000000   1589.000000  1582.000000      1199.000000
# mean      418.165346     0.561989      0.343612     1.110619         0.530442
# std      4850.671837     0.496299      0.475063     0.919822         0.499281
# ...

# %%
animals_df.Status.value_counts()
# Out:
# 0.0    1083
# 1.0     409
# Name: Status, dtype: int64

# %%
missing_status_df = copy_df[copy_df['Status'].isna()]

# %%
missing_status_df
# Out:
#                Scientific Name     Class            Order          Family  \
# 5       Chlamyphorus truncatus  mammalia        cingulata  chlamyphoridae
# 8        Sus scrofa domesticus  mammalia     artiodactyla          suidae
# 11         Canis lupus baileyi  mammalia        carnivora         canidae
# 13                  Bos taurus  mammalia     artiodactyla         bovidae
# 40    Canis lupus occidentalis  mammalia        carnivora         canidae
# ...                        ...       ...              ...             ...
# 1067          Bitis nasicornis  reptilia         squamata       viperidae
# 1077            Bothrops atrox  reptilia         squamata       viperidae
# 1081                Naja nivea  reptilia         squamata        elapidae
# 1197     Eudyptes (chrysocome)      aves  sphenisciformes    spheniscidae
# 1536         Anas carolinensis      aves     anseriformes        anatidae
#
#       Trend  Status  Life Span (years)  Length (cm)  Weight (kg)  Is Social  \
# ...

# %%
copy_df.set_index(keys = 'Scientific Name', drop=True, inplace=True)

# %% [markdown]
# ### We found missing Statuses and we filled it manually (using external resources)

# %%
copy_df
# Out:
#                                 Class          Order         Family  Trend  \
# Scientific Name
# Canis lupus arctos           mammalia      carnivora        canidae    NaN
# Vulpes lagopus               mammalia      carnivora        canidae    1.0
# Tamiasciurus hudsonicus      mammalia       rodentia      sciuridae    1.0
# Canis lupus                  mammalia      carnivora        canidae    1.0
# Mustela erminea              mammalia      carnivora     mustelidae    1.0
# ...                               ...            ...            ...    ...
# Melanerpes erythrocephalus       aves     piciformes        picidae    0.0
# Mniotilta varia                  aves  passeriformes      parulidae    0.0
# Leuconotopicus albolarvatus      aves     piciformes        picidae    1.0
# Dryobates borealis               aves     piciformes        picidae    0.0
# Cistothorus palustris            aves  passeriformes  troglodytidae    2.0
#
# ...

# %%
not_evaluated_status = ['Mazama americana', 'Canis lupus pallipes', 'Delphinus capensis', 'Hyperoodon ampullatus',
                        'Berardius bairdii', 'Mesoplodon traversii', 'Coluber constrictor priapus',
                       'Tragulus versicolor', 'Balaenoptera omurai', 'Cebus imitator', 'Naja naja', 'Chelonoidis carbonaria',
                       'Indotyphlops braminus', 'Eunectes murinus', 'Dendroaspis angusticeps', 'Daboia russelii', 
                       'Agama agama', 'Echis carinatus', 'Python sebae', 'Cerastes cerastes', 
                       'Bitis arietans', 'Bothrops asper', 'Anolis equestris', 'Ahaetulla nasuta',
                       'Naja haje', 'Epicrates cenchria', 'Varanus niloticus', 'Python molurus',
                        'Bitis gabonica', 'Boiga dendrophila', 'Ptyas mucosa', 'Boa constrictor', 
                       'Calotes versicolor', 'Crocodylus suchus', 'Naja oxiana', 'Aotus zonalis', 
                       'Bitis nasicornis', 'Naja nivea', 'Cricetulus griseus', 'Dasyprocta azarae']

animal_safe = ['Genus Ateles', 'Lama glama', 'Vicugna pacos', 'Canis dingo', 'Caperea marginata',
              'Equus africanus asinus', 'Stenella longirostris', 'Bos grunniens', 'Lagenorhynchus obscurus',
              'Stenella frontalis', 'Ovis aries', 'Genus Nomascus', 'Pseudorca crassidens',
              'Kogia sima', 'Canis lupus crassodon', 'Balaenoptera bonaerensis', 'Globicephala macrorhynchus',
              'Tursiops aduncus', 'Balaenoptera brydei', 'Mustela putorius furo', 
              'Lagenorhynchus australis', 'Cavia porcellus', 'Phocoena dioptrica', 'Mesoplodon densirostris', 
              'Mesoplodon europaeus', 'Sus scrofa domesticus',
              'Bos taurus', 'Canis lupus occidentalis', 'Canis anthus', 'Camelus dromedarius', 
              'Globicephala melas', 'Anolis sagrei', 'Chelus fimbriata', 'Eunectes notaeus',
              'Dispholidus typus', 'Bothrops atrox', 'Anas carolinensis', 'Chlamyphorus truncatus']

animal_not_safe = ['Canis lycaon', 'Camelus bactrianus', 'Inia geoffrensis', 'Bos frontalis',
                  'Tarsius pumilus', 'Orcinus orca', 'Loxodonta cyclotis', 'Sotalia fluviatilis',
                  'Cercopithecus lomamiensis', 'Bubalus bubalis', 'Canis lupus baileyi', 
                  'Cheirogaleus major', 'Cercocebus chrysogaster', 'Testudo kleinmanni',
                  'Chelonoidis nigra', 'Lachesis muta', 'Eudyptes (chrysocome)']

# %%
print(len(not_evaluated_status) + len(animal_safe) + len(animal_not_safe))
# Out:
# 95

# %%
for animal in not_evaluated_status:
    try:
        copy_df.drop(labels=animal, axis=0, inplace=True)
    except:
        print(animal)

# %%
for animal in animal_safe:
    try:
        copy_df.loc[animal, 'Status'] = 0
    except:
        print(animal)

# %%
for animal in animal_not_safe:
    try:
        copy_df.loc[animal, 'Status'] = 1
    except:
        print(animal)

# %%
copy_df.to_csv("animals updated data.csv")
